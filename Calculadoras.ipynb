# %%
print("Calculadora simples em Python")

while True:
    # Entrada de dados
    num1 = float(input("Digite o primeiro número: "))
    num2 = float(input("Digite o segundo número: "))

    # Escolha da operação
    print("\nEscolha a operação:")
    print("1 - Soma")
    print("2 - Subtração")
    print("3 - Multiplicação")
    print("4 - Divisão")

    escolha = input("Digite o número da operação desejada (1/2/3/4): ")

    # Condicional para executar a operação
    if escolha == "1":
        resultado = num1 + num2
        print(f"Resultado da soma: {resultado}")
    elif escolha == "2":
        resultado = num1 - num2
        print(f"Resultado da subtração: {resultado}")
    elif escolha == "3":
        resultado = num1 * num2
        print(f"Resultado da multiplicação: {resultado}")
    elif escolha == "4":
        if num2 != 0:
            resultado = num1 / num2
            print(f"Resultado da divisão: {resultado}")
        else:
            print("Erro: Divisão por zero não é permitida.")
    else:
        print("Operação inválida.")

    # Pergunta se o usuário quer continuar
    continuar = input("\nDeseja fazer outra operação? (s/n): ")
    if continuar.lower() != 's':
        print("Encerrando a calculadora. Até mais!")
        break
# Out:
# Calculadora simples em Python
# Digite o primeiro número: 10
# Digite o segundo número: 2
#
# Escolha a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# Digite o número da operação desejada (1/2/3/4): 3
# Resultado da multiplicação: 20.0
#
# Deseja fazer outra operação? (s/n): s
# Digite o primeiro número: 50
# Digite o segundo número: 2
#
# Escolha a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# Digite o número da operação desejada (1/2/3/4): 4
# Resultado da divisão: 25.0
#
# Deseja fazer outra operação? (s/n): n
# Encerrando a calculadora. Até mais!

# %%
import math

def menu():
    print("\n--- CALCULADORA CIENTÍFICA ---")
    print("1 - Soma")
    print("2 - Subtração")
    print("3 - Multiplicação")
    print("4 - Divisão")
    print("5 - Potência")
    print("6 - Raiz Quadrada")
    print("7 - Módulo (valor absoluto)")
    print("8 - Fatorial")
    print("9 - Sair")

while True:
    menu()
    opcao = input("Escolha uma opção (1-9): ")

    if opcao == "9":
        print("Encerrando a calculadora. Até logo!")
        break

    if opcao in ["1", "2", "3", "4", "5"]:
        num1 = float(input("Digite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))

        if opcao == "1":
            print(f"Resultado: {num1 + num2}")
        elif opcao == "2":
            print(f"Resultado: {num1 - num2}")
        elif opcao == "3":
            print(f"Resultado: {num1 * num2}")
        elif opcao == "4":
            if num2 != 0:
                print(f"Resultado: {num1 / num2}")
            else:
                print("Erro: divisão por zero.")
        elif opcao == "5":
            print(f"Resultado: {math.pow(num1, num2)}")

    elif opcao == "6":
        num = float(input("Digite o número: "))
        if num >= 0:
            print(f"Raiz quadrada de {num} é {math.sqrt(num)}")
        else:
            print("Erro: não é possível calcular raiz quadrada de número negativo.")

    elif opcao == "7":
        num = float(input("Digite o número: "))
        print(f"Módulo de {num} é {abs(num)}")

    elif opcao == "8":
        num = int(input("Digite um número inteiro: "))
        if num >= 0:
            print(f"Fatorial de {num} é {math.factorial(num)}")
        else:
            print("Erro: fatorial não definido para números negativos.")

    else:
        print("Opção inválida. Tente novamente.")
# Out:
# --- CALCULADORA CIENTÍFICA ---
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Potência
# 6 - Raiz Quadrada
# 7 - Módulo (valor absoluto)
# 8 - Fatorial
# 9 - Sair
# Escolha uma opção (1-9): 6
# Digite o número: 121
# Raiz quadrada de 121.0 é 11.0
#
# --- CALCULADORA CIENTÍFICA ---
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Potência
# 6 - Raiz Quadrada
# 7 - Módulo (valor absoluto)
# 8 - Fatorial
# 9 - Sair
# Escolha uma opção (1-9): 9
# Encerrando a calculadora. Até logo!
